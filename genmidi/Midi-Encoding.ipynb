# %%
import argparse
import random
import os
import numpy as np
from math import floor
from pyknon.genmidi import Midi
from pyknon.music import NoteSeq, Note
import music21
from pathlib import Path

import pandas as pd

# %%
VIOLINLIKE=["Violin", "Viola", "Cello", "Violincello", "Violoncello", "Flute", 
            "Oboe", "Clarinet", "Recorder", "Voice", "Piccolo",
            "StringInstrument", "Bassoon", "Horn"]
PIANOLIKE=["Piano", "Harp", "Harpsichord", "Organ", ""]

# %%
from music21 import converter, corpus, instrument, midi, note, chord, pitch

# %%
file = converter.parse('C:/Users/B/Desktop/midis/Nintendo/DKR/Hauntedwoods.mid')

# %%
file.show('midi')
# Out:
#                 <div id='midiPlayerDiv16873'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv16873');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
for f in file:
    for i in f:
        print(i)

# %%
for j in f:
    print(j)
