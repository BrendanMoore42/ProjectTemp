# %%
import pandas as pd

# %%
df = pd.read_html('https://web.njit.edu/~kevin/rgb.txt.html')

# %%
df[2]
# Out:
#                                                     0        1            2  \
# 0    Shades of Black and Gray (see also Gray vs Grey)      NaN          NaN
# 1                                          Color Name  Credits    R;G;B Dec
# 2                                                Grey        N     84;84;84
# 3                                        Grey, Silver        V  192;192;192
# 4                                                grey        X  190;190;190
# 5                                           LightGray        X  211;211;211
# 6                                      LightSlateGrey        X  119;136;153
# 7                                           SlateGray        X  112;128;144
# 8                                          SlateGray1        X  198;226;255
# 9                                          SlateGray2        X  185;211;238
# 10                                         SlateGray3        X  159;182;205
# ...
